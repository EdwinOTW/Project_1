# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# How to increase the participation rate for SAT and ACT exams among graduates in Alaska.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017[0:10]
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017[:10]
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# The sat_2017.csv describes the average SAT scores achieved in each different states and the participation rates in each state. The scores are split into columns based on Evidence-Based Reading and Writing, and Math. There is also the Total column which represents Evidence_based Reading and Write + Math.
#
# act_2017.csv describes the average ACT scores achieved in differenct states and the participation rates in each state. The tests are comprised of English, Math, Reading, Science and their average values are in the corresponding columns. The composite column represents the overall score in the ACT test. The National average of the ACT scores are also shown in row[0].
#
# Each value in the columns represents the average scores of the different states.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# Yes the data looks complete based on the first 10 rows. There doesn't seem to have any missing values or N/A.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# The minimum values and maximum values for each test/subtest have been identified below.

# %%
sat_2017.iloc[:, 2:5].min()
# Out:
# Evidence-Based Reading and Writing    482
# Math                                   52
# Total                                 950
# dtype: int64

# %%
act_2017.iloc[:, 2:7].min()
# Out:
# English      16.3
# Math         18.0
# Reading      18.1
# Science       2.3
# Composite    17.8
# dtype: float64

# %%
sat_2017.iloc[:, 2:5].max()
# Out:
# Evidence-Based Reading and Writing     644
# Math                                   651
# Total                                 1295
# dtype: int64

# %%
act_2017.iloc[:, 2:7].max()
# Out:
# English      25.5
# Math         25.3
# Reading      26.0
# Science      24.9
# Composite    25.5
# dtype: float64

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# After looking through the data for sat_2017, I discovered that the value of Math for the state "Maryland" was 52, which was incorrect. From this website (https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/) , the actual value for Math is 524.

# %%
# Maryland Math Score is incorrect. Correct Value is 524
# for i in sat_2017['State']:
#     if i == "Maryland" :
        
sat_2017["Math"] = sat_2017["Math"].apply(lambda x : 524 if x == 52 else x)
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# After looking through the data for act_2017, I discovered that the value for column "Science" for the State "Maryland" (again) was 2.3, which is incorrect. From this website (https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows) , the actual value is 23.2.

# %%
act_2017["Science"] = act_2017["Science"].apply(lambda x : 23.2 if x == 2.3 else x)
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# Data Type for each column in the SAT table
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Data Type for each column in the ACT table
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# Some of the Columns are not what they should be.
# For the SAT_2017 table, participation should be a float instead of an object.
# Evidence-Based Reading and Writing, Math and Total should be float instead of integer to have more accurate results.
#
# For ACT_2017 table, participation should also be a float instead of an object.
# The datatype for Composite should be a float instead of an object as well.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# Convert Participation Rates from String to float
def convert_rates(x):
    #remove % , change str to float and change to decimal places
    try:
        return float(x.replace('%', ""))/100
    except:
        return (x)

# %%
# Convert SAT 2017
sat_2017["Participation"] = sat_2017["Participation"].apply(lambda x : convert_rates(x))

# %%
# Convert ACT 2017
act_2017["Participation"] = act_2017["Participation"].apply(lambda x : convert_rates(x))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
## convert column "a" to int64 dtype and "b" to complex type
# Convert SAT column datatype
sat_2017 = sat_2017.astype({"Evidence-Based Reading and Writing": float, "Math": float, "Total": float})

# %%
# Fixed the Composite column
act_2017["Composite"] = act_2017["Composite"].apply(lambda x : x.replace("x",""))

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing   Math  \
# 0     Alabama           0.05                               593.0  572.0
# 1      Alaska           0.38                               547.0  533.0
# 2     Arizona           0.30                               563.0  553.0
# 3    Arkansas           0.03                               614.0  594.0
# 4  California           0.53                               531.0  524.0
#
#     Total
# 0  1165.0
# 1  1080.0
# 2  1116.0
# 3  1208.0
# 4  1055.0

# %%
# Convert ACT column datatype
act_2017 = act_2017.astype({"Composite": float})
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code: SAT Data Types
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %%
# ACT Data Types
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
def convert_name(x, data_name):
    if x == "State":
        return x.lower()
    elif x == x.lower():
        return x
    else:
        try:
            x = x.replace(" ", "_").lower() + "_" + data_name
            return x
        except:
            return x

# %%
# Rename Sat_2017
sat_2017 = sat_2017.rename(columns = lambda x : convert_name(x, "sat_17"))
sat_2017.head()
# Out:
#         state  participation_sat_17  \
# 0     Alabama                  0.05
# 1      Alaska                  0.38
# 2     Arizona                  0.30
# 3    Arkansas                  0.03
# 4  California                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17
# 0                                      593.0        572.0        1165.0
# 1                                      547.0        533.0        1080.0
# 2                                      563.0        553.0        1116.0
# 3                                      614.0        594.0        1208.0
# 4                                      531.0        524.0        1055.0

# %%
# Rename Act_2017
act_2017 = act_2017.rename(columns = lambda x : convert_name(x, "act_17"))
act_2017.head()
# Out:
#       state  participation_act_17  english_act_17  math_act_17  \
# 0  National                  0.60            20.3         20.7
# 1   Alabama                  1.00            18.9         18.4
# 2    Alaska                  0.65            18.7         19.8
# 3   Arizona                  0.62            18.6         19.8
# 4  Arkansas                  1.00            18.9         19.0
#
#    reading_act_17  science_act_17  composite_act_17
# 0            21.4            21.0              21.0
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# <h1><center>SAT & ACT Data Dictionary</center></h1>
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT 2017| Different states in United States|
# |participation_act_17|float|ACT 2017| Participation rates for ACTs in the different states in United States(Units: Example 0.1 = 10%)|
# |english_act_17|float|ACT 2017| Average score for English in the different states in United States|
# |math_act_17|float|ACT 2017| Average score for Mathematics in the different states in United States|
# |reading_act_17|float|ACT 2017| Average score for Reading in the different states in United States|
# |science_act_17|float|ACT 2017| Average score for Science in the different states in United States|
# |composite_act_17|float|ACT 2017| Average Composite score in the different states in United States|
# |state|object|SAT 2017| Different states in United States|
# |participation_sat_17|float|SAT 2017| Participation rates for SATs in the different states in United States(Units: Example 0.1 = 10%)|
# |evidence-based_reading_and_writing_sat_17|float|SAT 2017| Average score for Evidence-Based Reading and Writing in the different states in United States|
# |math_sat_17|float|SAT 2017| Average score for Mathematics in the different states in United States|
# |total_sat_17|float|SAT 2017| Average Total score in the different states in United States|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act_2017.iloc[0,0]
# Out:
# 'National'

# %%
# Remove Row Displaying National Values
if act_2017.iloc[0,0] == 'National':
    act_2017 = act_2017.drop(0).reset_index(drop=True)
act_2017.head()
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17
# 0            19.7            19.4              19.2
# 1            20.4            19.9              19.8
# 2            20.1            19.8              19.7
# 3            19.7            19.5              19.4
# 4            23.1            22.2              22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
act_2017.dtypes
# Out:
# state                    object
# participation_act_17    float64
# english_act_17          float64
# math_act_17             float64
# reading_act_17          float64
# science_act_17          float64
# composite_act_17        float64
# dtype: object

# %%
sat_2017.dtypes
# Out:
# state                                         object
# participation_sat_17                         float64
# evidence-based_reading_and_writing_sat_17    float64
# math_sat_17                                  float64
# total_sat_17                                 float64
# dtype: object

# %%
combined_2017 = pd.merge(act_2017, sat_2017, on = "state")
combined_2017.head()
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17  participation_sat_17  \
# 0            19.7            19.4              19.2                  0.05
# 1            20.4            19.9              19.8                  0.38
# 2            20.1            19.8              19.7                  0.30
# 3            19.7            19.5              19.4                  0.03
# 4            23.1            22.2              22.8                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17
# ...

# %%
# Code: Testing the Join Method
## act_2017.set_index("state").join(sat_2017.set_index("state"))

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#Save Dataframe to data folder as csv
combined_2017.to_csv("../data/combined_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# ## 1. Import Data

# %%
# Importing 2018 ACT and 2018 SAT Data
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %% [markdown]
# ## 2. Display Data
# Display first 10 rows of each DataFrame

# %%
# Display SAT_2018
sat_2018[:10]
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
# Display ACT_2018
act_2018[:10]
# Out:
#                   State Participation  Composite
# 0               Alabama          100%       19.1
# 1                Alaska           33%       20.8
# 2               Arizona           66%       19.2
# 3              Arkansas          100%       19.4
# 4            California           27%       22.7
# 5              Colorado           30%       23.9
# 6           Connecticut           26%       25.6
# 7              Delaware           17%       23.8
# 8  District of columbia           32%       23.6
# 9               Florida           66%       19.9

# %% [markdown]
# ## 3. Describe Data

# %% [markdown]
# The sat_2017.csv describes the average SAT scores achieved in each different states and the participation rates in each state. The scores are split into columns based on Evidence-Based Reading and Writing, and Math. There is also the Total column which represents Evidence_based Reading and Write + Math.
#
# act_2017.csv describes the average ACT scores achieved in differenct states and the participation rates in each state. The composite column represents the overall score in the ACT test based of from English, Math, Reading, Science.
#
# Each value in the columns represents the average scores of the different states.

# %% [markdown]
# ## 4. Does Data look complete?
# No, act_2018 data looks incomplete. There are missing columns for English, Math, Reading and Science scores.
# Duplicates were also found in the data.

# %% [markdown]
# 4.1. Fix any errors found

# %% [markdown]
# 4.1.1. Import new act_2018 data

# %%
# Data Imported is from (https://magoosh.com/hs/act/2016/average-act-score-by-state/) 
act_2018_full = pd.read_csv("../data/act_2018_full.csv")
act_2018_full.head()
# Out:
#         State Percentage of Students Tested  Average Composite Score  English  \
# 0     Alabama                           100                     19.1     18.9
# 1      Alaska                            33                     20.8     19.8
# 2     Arizona                            66                     19.2     18.2
# 3    Arkansas                           100                     19.4     19.1
# 4  California                            27                     22.7     22.5
#
#    Math  Reading  Science
# 0  18.3     19.6     19.0
# 1  20.6     21.6     20.7
# 2  19.4     19.5     19.2
# 3  18.9     19.7     19.4
# 4  22.5     23.0     22.1

# %% [markdown]
# 4.1.2. Remove unnecessary rows from data

# %%
# Remove duplicate data from act_2018 data
act_2018 = act_2018.drop_duplicates("State").reset_index(drop=True)
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Remove 'National' State from act_2018_full, reset index from 0 to 50
act_2018_full = act_2018_full.drop([27,28]).reset_index(drop=True)
act_2018_full.head()
# Out:
#         State Percentage of Students Tested  Average Composite Score  English  \
# 0     Alabama                           100                     19.1     18.9
# 1      Alaska                            33                     20.8     19.8
# 2     Arizona                            66                     19.2     18.2
# 3    Arkansas                           100                     19.4     19.1
# 4  California                            27                     22.7     22.5
#
#    Math  Reading  Science
# 0  18.3     19.6     19.0
# 1  20.6     21.6     20.7
# 2  19.4     19.5     19.2
# 3  18.9     19.7     19.4
# 4  22.5     23.0     22.1

# %% [markdown]
# 4.2.3. Merge act_2018 with act_2018_full to get the complete data for ACT 2018 exams

# %%
# Merge both dataframes together
final_act_2018 = pd.merge(act_2018, act_2018_full, on = "State")
final_act_2018.head()
# Out:
#         State Participation  Composite Percentage of Students Tested  \
# 0     Alabama          100%       19.1                           100
# 1      Alaska           33%       20.8                            33
# 2     Arizona           66%       19.2                            66
# 3    Arkansas          100%       19.4                           100
# 4  California           27%       22.7                            27
#
#    Average Composite Score  English  Math  Reading  Science
# 0                     19.1     18.9  18.3     19.6     19.0
# 1                     20.8     19.8  20.6     21.6     20.7
# 2                     19.2     18.2  19.4     19.5     19.2
# 3                     19.4     19.1  18.9     19.7     19.4
# 4                     22.7     22.5  22.5     23.0     22.1

# %%
# Remove Duplicate columns
final_act_2018 = final_act_2018.drop(['Percentage of Students Tested', 'Average Composite Score'], 1)
final_act_2018.head()
# Out:
#         State Participation  Composite  English  Math  Reading  Science
# 0     Alabama          100%       19.1     18.9  18.3     19.6     19.0
# 1      Alaska           33%       20.8     19.8  20.6     21.6     20.7
# 2     Arizona           66%       19.2     18.2  19.4     19.5     19.2
# 3    Arkansas          100%       19.4     19.1  18.9     19.7     19.4
# 4  California           27%       22.7     22.5  22.5     23.0     22.1

# %% [markdown]
# ## 5. Check Datatype

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
final_act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# dtype: object

# %% [markdown]
# sat_2018 - Participation, Evidence Based Reading and Writing, Math and Total should be changed to float
#
# final_act_2018 - Participation should be changed to float

# %% [markdown]
# ## 6. Fix incorrect Datatypes

# %%
# Change final_act_2018 participation datatype to float
final_act_2018["Participation"] = final_act_2018["Participation"].apply(lambda x : convert_rates(x))
final_act_2018.head()
final_act_2018.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# dtype: object

# %%
# Change sat_2018 participation datatype to float
sat_2018["Participation"] = sat_2018["Participation"].apply(lambda x : convert_rates(x))
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
sat_2018 = sat_2018.astype({"Evidence-Based Reading and Writing": float, "Math": float, "Total": float})
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %% [markdown]
# ## 7. Rename Columns

# %%
final_act_2018 = final_act_2018.rename(columns = lambda x : convert_name(x, "act_18"))
final_act_2018.head()
# Out:
#         state  participation_act_18  composite_act_18  english_act_18  \
# 0     Alabama                  1.00              19.1            18.9
# 1      Alaska                  0.33              20.8            19.8
# 2     Arizona                  0.66              19.2            18.2
# 3    Arkansas                  1.00              19.4            19.1
# 4  California                  0.27              22.7            22.5
#
#    math_act_18  reading_act_18  science_act_18
# 0         18.3            19.6            19.0
# 1         20.6            21.6            20.7
# 2         19.4            19.5            19.2
# 3         18.9            19.7            19.4
# 4         22.5            23.0            22.1

# %%
sat_2018 = sat_2018.rename(columns = lambda x : convert_name(x, "sat_18"))
sat_2018.head()
# Out:
#         state  participation_sat_18  \
# 0     Alabama                  0.06
# 1      Alaska                  0.43
# 2     Arizona                  0.29
# 3    Arkansas                  0.05
# 4  California                  0.60
#
#    evidence-based_reading_and_writing_sat_18  math_sat_18  total_sat_18
# 0                                      595.0        571.0        1166.0
# 1                                      562.0        544.0        1106.0
# 2                                      577.0        572.0        1149.0
# 3                                      592.0        576.0        1169.0
# 4                                      540.0        536.0        1076.0

# %% [markdown]
# ## 8. Create Data Dictionary

# %% [markdown]
# <h1><center>SAT & ACT Data Dictionary</center></h1>
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|final_act_2018| Different states in United States|
# |participation_act_18|float|final_act_2018| Participation rates for ACTs in the different states in United States(Units: Example 0.1 = 10%)|
# |english_act_18|float|final_act_2018| Average score for English in the different states in United States|
# |math_act_18|float|final_act_2018| Average score for Mathematics in the different states in United States|
# |reading_act_18|float|final_act_2018| Average score for Reading in the different states in United States|
# |science_act_18|float|final_act_2018| Average score for Science in the different states in United States|
# |composite_act_18|float|final_act_2018| Average Composite score in the different states in United States|
# |state|object|sat_2018| Different states in United States|
# |participation_sat_18|float|sat_2018| Participation rates for SATs in the different states in United States(Units: Example 0.1 = 10%)|
# |evidence-based_reading_and_writing_sat_18|float|sat_2018| Average score for Evidence-Based Reading and Writing in the different states in United States|
# |math_sat_18|float|sat_2018| Average score for Mathematics in the different states in United States|
# |total_sat_18|float|sat_2018| Average Total score in the different states in United States|

# %% [markdown]
# ## 9. Drop any unnecessary rows/columns

# %% [markdown]
# Unnecessary Rows and Columns have already been dropped in Part 4

# %% [markdown]
# ## 10. Merge DataFrames

# %%
combined_2018 = pd.merge(final_act_2018, sat_2018, on = "state")
combined_2018.head()
# Out:
#         state  participation_act_18  composite_act_18  english_act_18  \
# 0     Alabama                  1.00              19.1            18.9
# 1      Alaska                  0.33              20.8            19.8
# 2     Arizona                  0.66              19.2            18.2
# 3    Arkansas                  1.00              19.4            19.1
# 4  California                  0.27              22.7            22.5
#
#    math_act_18  reading_act_18  science_act_18  participation_sat_18  \
# 0         18.3            19.6            19.0                  0.06
# 1         20.6            21.6            20.7                  0.43
# 2         19.4            19.5            19.2                  0.29
# 3         18.9            19.7            19.4                  0.05
# 4         22.5            23.0            22.1                  0.60
#
#    evidence-based_reading_and_writing_sat_18  math_sat_18  total_sat_18
# ...

# %%
# Saved combined_2018 to csv
combined_2018.to_csv("../data/combined_2018.csv")

# %% [markdown]
# ## 11. Save Combined DataFrames

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Merged combined dataframes and save to CSV
final = pd.merge(combined_2017, combined_2018, on = "state")
final.to_csv("../data/final.csv")
final.head(10)
# Out:
#          state  participation_act_17  english_act_17  math_act_17  \
# 0      Alabama                  1.00            18.9         18.4
# 1       Alaska                  0.65            18.7         19.8
# 2      Arizona                  0.62            18.6         19.8
# 3     Arkansas                  1.00            18.9         19.0
# 4   California                  0.31            22.5         22.7
# 5     Colorado                  1.00            20.1         20.3
# 6  Connecticut                  0.31            25.5         24.6
# 7     Delaware                  0.18            24.1         23.4
# 8      Florida                  0.73            19.0         19.4
# 9      Georgia                  0.55            21.0         20.9
#
#    reading_act_17  science_act_17  composite_act_17  participation_sat_17  \
# 0            19.7            19.4              19.2                  0.05
# 1            20.4            19.9              19.8                  0.38
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe()
# Out:
#        participation_act_17  english_act_17  math_act_17  reading_act_17  \
# count             50.000000       50.000000     50.00000       50.000000
# mean               0.659200       20.862000     21.13600       21.956000
# std                0.321107        2.324307      1.97399        2.046317
# min                0.080000       16.300000     18.00000       18.100000
# 25%                0.310000       19.000000     19.40000       20.425000
# 50%                0.710000       20.550000     20.90000       21.700000
# 75%                1.000000       23.100000     23.00000       23.875000
# max                1.000000       25.500000     25.30000       26.000000
#
#        science_act_17  composite_act_17  participation_sat_17  \
# count       50.000000         50.000000             50.000000
# mean        21.410000         21.466000              0.386000
# std          1.731962          2.004241              0.345602
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
final.dtypes
# Out:
# state                                         object
# participation_act_17                         float64
# english_act_17                               float64
# math_act_17                                  float64
# reading_act_17                               float64
# science_act_17                               float64
# composite_act_17                             float64
# participation_sat_17                         float64
# evidence-based_reading_and_writing_sat_17    float64
# math_sat_17                                  float64
# total_sat_17                                 float64
# participation_act_18                         float64
# composite_act_18                             float64
# english_act_18                               float64
# math_act_18                                  float64
# reading_act_18                               float64
# science_act_18                               float64
# participation_sat_18                         float64
# ...

# %%
#code
a = [3,4,5,3,4,4,4]
def standard_deviation(x):
    # x is the array
    x_mean = np.mean(x)
    return np.sqrt(np.sum([np.square(e-x_mean) for e in x])/len(x))
standard_deviation(a)
# Out:
# 0.6388765649999398

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code: Manual Standard deviation method
{col : standard_deviation(final[col]) for col in final.columns if col != 'state'}
# Out:
# {'participation_act_17': 0.3178794740149165,
#  'english_act_17': 2.3009467616613817,
#  'math_act_17': 1.9541504548012676,
#  'reading_act_17': 2.025750231395766,
#  'science_act_17': 1.7145553359399048,
#  'composite_act_17': 1.9840977798485637,
#  'participation_sat_17': 0.3421286307808804,
#  'evidence-based_reading_and_writing_sat_17': 43.9390532442382,
#  'math_sat_17': 45.37911854586864,
#  'total_sat_17': 89.00941298536914,
#  'participation_act_18': 0.3377125404837671,
#  'composite_act_18': 2.0900918640098096,
#  'english_act_18': 2.415500776236679,
#  'math_act_18': 2.023305216718427,
#  'reading_act_18': 2.1403214711813736,
#  'science_act_18': 1.8551161688692166,
#  'participation_sat_18': 0.3672475459414263,
#  'evidence-based_reading_and_writing_sat_18': 46.5379372125581,
#  'math_sat_18': 46.51518461749883,
#  'total_sat_18': 91.9124888140888}

# %%
# Numpy std method
{col : np.std(final[col]) for col in final.columns if col != 'state'}
# Out:
# {'participation_act_17': 0.3178794740149165,
#  'english_act_17': 2.3009467616613812,
#  'math_act_17': 1.9541504548012678,
#  'reading_act_17': 2.025750231395766,
#  'science_act_17': 1.7145553359399048,
#  'composite_act_17': 1.9840977798485642,
#  'participation_sat_17': 0.3421286307808805,
#  'evidence-based_reading_and_writing_sat_17': 43.9390532442382,
#  'math_sat_17': 45.37911854586864,
#  'total_sat_17': 89.00941298536914,
#  'participation_act_18': 0.33771254048376703,
#  'composite_act_18': 2.090091864009809,
#  'english_act_18': 2.4155007762366796,
#  'math_act_18': 2.0233052167184264,
#  'reading_act_18': 2.1403214711813736,
#  'science_act_18': 1.8551161688692166,
#  'participation_sat_18': 0.36724754594142633,
#  'evidence-based_reading_and_writing_sat_18': 46.537937212558106,
#  'math_sat_18': 46.51518461749884,
#  'total_sat_18': 91.91248881408882}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
#
# No. The manual calculated standard deviations is a little bit different from the output from pandas describe method.
#
# Numpy's std method produced the same results are the manually calculated standard deviations.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:

# %% [markdown]
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %% [markdown]
# ## ACT 2017

# %%
# Highest Participation for ACT 2017
final_act_17 = final.iloc[:,:2]
final_act_17.sort_values(by = "participation_act_17",ascending=False).head()
# Out:
#         state  participation_act_17
# 0     Alabama                   1.0
# 16   Kentucky                   1.0
# 48  Wisconsin                   1.0
# 43       Utah                   1.0
# 41  Tennessee                   1.0

# %%
# Lowest Participation for ACT 2017
final_act_17.sort_values(by = "participation_act_17").head()
# Out:
#             state  participation_act_17
# 18          Maine                  0.08
# 7        Delaware                  0.18
# 28  New Hampshire                  0.18
# 38   Rhode Island                  0.21
# 37   Pennsylvania                  0.23

# %% [markdown]
# Highest Participation Rate ACT 2017 : Alabama, Kentucky, Wisconsin, Utah, Tennessee
#
# Lowest Participation Rate ACT 2017 : Maine, Delaware, New Hampshire, Rhode Island, Pennsylvania

# %% [markdown]
# ## SAT 2017

# %%
# Highest Participation for SAT 2017
final_sat_17 = final[['state','participation_sat_17']]
final_sat_17.sort_values(by='participation_sat_17', ascending=False).head()
# Out:
#             state  participation_sat_17
# 21       Michigan                  1.00
# 6     Connecticut                  1.00
# 7        Delaware                  1.00
# 28  New Hampshire                  0.96
# 18          Maine                  0.95

# %%
# Lowest Participation for SAT 2017

final_sat_17.sort_values(by='participation_sat_17', ascending=True).head()
# Out:
#            state  participation_sat_17
# 33  North Dakota                  0.02
# 23   Mississippi                  0.02
# 14          Iowa                  0.02
# 24      Missouri                  0.03
# 43          Utah                  0.03

# %% [markdown]
# Highest Participation Rate SAT 2017 : Michigan, Connecticut, Delaware, New Hampshire, Maine
#
# Lowest Participation Rate SAT 2017 : North Dakota, Mississippi, Iowa, Missouri, Utah

# %% [markdown]
# ## ACT 2018

# %%
# Highest Participation for ACT 2018
final_act_18 = final[['state','participation_act_18']]
final_act_18.sort_values(by='participation_act_18', ascending=False).head()
# Out:
#         state  participation_act_18
# 0     Alabama                   1.0
# 16   Kentucky                   1.0
# 48  Wisconsin                   1.0
# 43       Utah                   1.0
# 41  Tennessee                   1.0

# %%
# Lowest Participation for ACT 2018

final_act_18.sort_values(by='participation_act_18', ascending=True).head()
# Out:
#             state  participation_act_18
# 18          Maine                  0.07
# 38   Rhode Island                  0.15
# 28  New Hampshire                  0.16
# 7        Delaware                  0.17
# 37   Pennsylvania                  0.20

# %% [markdown]
# Highest Participation Rate ACT 2018 : Alabama, Kentucky, Wisconsin, Utah, Tennessee
#
# Lowest Participation Rate ACT 2018 : Maine, Rhode Island, New Hampshire, Delaware, Pennsylvania

# %% [markdown]
# ## SAT 2018

# %%
# Highest Participation for SAT 2018
final_sat_18 = final[['state','participation_sat_18']]
final_sat_18.sort_values(by='participation_sat_18', ascending=False).head()
# Out:
#           state  participation_sat_18
# 5      Colorado                   1.0
# 6   Connecticut                   1.0
# 7      Delaware                   1.0
# 21     Michigan                   1.0
# 11        Idaho                   1.0

# %%
# Lowest Participation for SAT 2018
final_sat_18.sort_values(by='participation_sat_18', ascending=True).head()
# Out:
#            state  participation_sat_18
# 33  North Dakota                  0.02
# 49       Wyoming                  0.03
# 40  South Dakota                  0.03
# 26      Nebraska                  0.03
# 48     Wisconsin                  0.03

# %% [markdown]
# Highest Participation Rate SAT 2018 : Colorado, Connecticut, Delaware, Michigan, Idaho
#
# Lowest Participation Rate SAT 2018 : North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %% [markdown]
# ## ACT 2017

# %%
# Highest mean composite scores
final_act_17_mean = final[['state','composite_act_17']]
final_act_17_mean.sort_values(by='composite_act_17', ascending=False).head()
# Out:
#             state  composite_act_17
# 28  New Hampshire              25.5
# 20  Massachusetts              25.4
# 6     Connecticut              25.2
# 18          Maine              24.3
# 31       New York              24.2

# %%
# Lowest mean composite scores
final_act_17_mean.sort_values(by='composite_act_17', ascending=True).head()
# Out:
#              state  composite_act_17
# 27          Nevada              17.8
# 23     Mississippi              18.6
# 39  South Carolina              18.7
# 10          Hawaii              19.0
# 32  North Carolina              19.1

# %% [markdown]
# States with the highest mean composite ACT 2017 score : New Hampshire, Massachisetts, Connecticut, Maine, New York
#
# States with the lowest mean composite ACT 2017 score : Nevada, Mississippi, South Carolina, Hawaii, North Carolina

# %% [markdown]
# ## SAT 2017

# %%
# Highest mean total scores
final_sat_17_mean = final[['state','total_sat_17']]
final_sat_17_mean.sort_values(by='total_sat_17', ascending=False).head()
# Out:
#         state  total_sat_17
# 22  Minnesota        1295.0
# 48  Wisconsin        1291.0
# 14       Iowa        1275.0
# 24   Missouri        1271.0
# 15     Kansas        1260.0

# %%
# Lowest mean composite scores
final_sat_17_mean.sort_values(by='total_sat_17', ascending=True).head()
# Out:
#        state  total_sat_17
# 7   Delaware         996.0
# 11     Idaho        1005.0
# 21  Michigan        1005.0
# 18     Maine        1012.0
# 8    Florida        1017.0

# %% [markdown]
# States with the highest mean SAT 2017 Score : Minnesota, Wisconsin, Iowa, Missouri, Kansas
#
# States with the lowest mean SAT 2017 Score : Delaware, Idaho, Michigan, Maine, Florida

# %% [markdown]
# ## ACT 2018

# %%
# Highest mean composite scores act_2018
final_act_18_mean = final[['state','composite_act_18']]
final_act_18_mean.sort_values(by='composite_act_18', ascending=False).head()
# Out:
#             state  composite_act_18
# 6     Connecticut              25.6
# 20  Massachusetts              25.5
# 28  New Hampshire              25.1
# 31       New York              24.5
# 21       Michigan              24.2

# %%
# lowest mean composite scores act_2018
final_act_18_mean.sort_values(by='composite_act_18', ascending=True).head()
# Out:
#              state  composite_act_18
# 27          Nevada              17.7
# 39  South Carolina              18.3
# 23     Mississippi              18.6
# 10          Hawaii              18.9
# 0          Alabama              19.1

# %% [markdown]
# States with highest mean composite score ACT 2018 :  Connecticut, Massachisetts, New Hampshire, New York, Michigan
#
# States with lowest mean composite score ACT 2018 : Nevada, South Carolina, Mississippi, Hawaii, Alabama

# %% [markdown]
# ## SAT 2018

# %%
# Highest mean Total scores sat_2018
final_sat_18_mean = final[['state','total_sat_18']]
final_sat_18_mean.sort_values(by='total_sat_18', ascending=False).head()
# Out:
#            state  total_sat_18
# 22     Minnesota        1298.0
# 48     Wisconsin        1294.0
# 33  North Dakota        1283.0
# 14          Iowa        1265.0
# 15        Kansas        1265.0

# %%
# Lowest mean Total scores sat_2018
final_sat_18_mean.sort_values(by='total_sat_18', ascending=True).head()
# Out:
#             state  total_sat_18
# 7        Delaware         998.0
# 47  West Virginia         999.0
# 11          Idaho        1001.0
# 43           Utah        1010.0
# 10         Hawaii        1010.0

# %% [markdown]
# States with the highest mean total score SAT 2018 : Minnesota, Wisconsin, North Dakota, Iowa, Kansas
#
# States with the lowest mean total score SAT 2018 : Delaware, West Virginia, Idaho, Utah, Hawaii

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?

# %% [markdown]
# ## ACT Exams

# %%
final[(final["participation_act_17"] == 1)|(final["participation_act_18"] == 1)][['state', 'participation_act_17','participation_act_18']]
# Out:
#              state  participation_act_17  participation_act_18
# 0          Alabama                  1.00                  1.00
# 3         Arkansas                  1.00                  1.00
# 5         Colorado                  1.00                  0.30
# 16        Kentucky                  1.00                  1.00
# 17       Louisiana                  1.00                  1.00
# 22       Minnesota                  1.00                  0.99
# 23     Mississippi                  1.00                  1.00
# 24        Missouri                  1.00                  1.00
# 25         Montana                  1.00                  1.00
# 26        Nebraska                  0.84                  1.00
# 27          Nevada                  1.00                  1.00
# 32  North Carolina                  1.00                  1.00
# 34            Ohio                  0.75                  1.00
# 35        Oklahoma                  1.00                  1.00
# ...

# %% [markdown]
# For the ACT exams, Minniesota had a rate change from 100% to 99% (2017 to 2018), Colorado had a rate change from 100% to 30% (2017 to 2018). Ohio on the other hand, went from 75% to 100% participation (2017 to 2018) and Nebraska went from 84% to 100% participation (2017 to 2018).

# %% [markdown]
# ## SAT Exams

# %%
final[(final["participation_sat_17"] == 1)|(final["participation_sat_18"] == 1)][['state', 'participation_sat_17','participation_sat_18']]
# Out:
#           state  participation_sat_17  participation_sat_18
# 5      Colorado                  0.11                   1.0
# 6   Connecticut                  1.00                   1.0
# 7      Delaware                  1.00                   1.0
# 11        Idaho                  0.93                   1.0
# 21     Michigan                  1.00                   1.0

# %% [markdown]
# For SAT exams, Colorado went from 11% participation in 2017 to 100% participation in 2018 and Idaho went from 93% participation in 2017 to 100% participation in 2018

# %% [markdown]
# - Do any states show have >50% participation on *both* tests either year?

# %% [markdown]
# ## 2017

# %%
final[(final["participation_sat_17"] > 0.5)&(final["participation_act_17"] > 0.5)][['state', 'participation_sat_17','participation_act_17']]
# Out:
#       state  participation_sat_17  participation_act_17
# 8   Florida                  0.83                  0.73
# 9   Georgia                  0.61                  0.55
# 10   Hawaii                  0.55                  0.90

# %% [markdown]
# Florida, Georgia, Hawaii have more than 50% participation for both tests on 2017

# %% [markdown]
# ## 2018

# %%
final[(final["participation_sat_18"] > 0.5)&(final["participation_act_18"] > 0.5)][['state', 'participation_sat_18','participation_act_18']]
# Out:
#              state  participation_sat_18  participation_act_18
# 8          Florida                  0.56                  0.66
# 9          Georgia                  0.70                  0.53
# 10          Hawaii                  0.56                  0.89
# 32  North Carolina                  0.52                  1.00
# 39  South Carolina                  0.55                  1.00

# %% [markdown]
# Forida, Georgia, Hawaii, North Carolina, South Carolina have more than 50% participation for both tests on 2018

# %% [markdown]
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# Utah: Utah had a sudden jump in participation rates for ACT exams from 2017 to 2018. Why?
#
# Colarado: Colarado participation for SAT went from 11% to 100% but ACT went from 100% to 30%. Why?

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
sns.heatmap(final.corr())

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,12)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels)
        ax[i].set_ylabel('Number of States')
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Participation rates for SAT & ACT
subplot_histograms(final,['participation_act_17', 'participation_sat_17', 'participation_act_18', 'participation_sat_18'], ["Participation rates ACT 2017", "Participation rates SAT 2017", "Participation rates ACT 2018", "Participation rates SAT 2018"], "Participation Rates")

# %% [markdown]
# Most States in the United States choose to sit for the ACT exams instead of the SAT exams in 2017 and 2018 although there is a slight increase in States that went for SAT exams in 2018.
#
# From the Bar chart, it would seem that the ACT plot is similar to a mirror reflection of the SAT plot. This tells me that most people in the states either went for the SAT exams or the ACT exams. Although there is a possibility some people went for both, or did not take either exams.

# %%
# Math Scores for ACT and SAT
subplot_histograms(final,['math_act_17', 'math_sat_17', 'math_act_18', 'math_sat_18'], ["Math Score ACT 2017", "Math Score SAT 2017", "Math Score ACT 2018", "Math Score SAT 2018"], "Average Math Score")

# %% [markdown]
# There is are slight improvements in results ACT exams and SAT exams in the states from 2017 to 2018

# %%
# Reading and VErbal Scores ACT and SAT
subplot_histograms(final,['reading_act_17', 'evidence-based_reading_and_writing_sat_17', 'reading_act_18', 'evidence-based_reading_and_writing_sat_18'], ["Reading Score ACT 2017", "Reading Score SAT 2017", "Reading Score ACT 2018", "Reading Score SAT 2018"], "Average Reading Score")

# %% [markdown]
# Average reading scores are pretty consistent over the years. Not much change in results.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# ## SAT vs ACT Math scores 2017

# %%
# Code
# Establish the size of the figure.
plt.figure(figsize=(12, 6))

# Create scatter plot of SAT versus ACT 2017.
plt.scatter(final['math_sat_17'],
            final['math_act_17']);

plt.title("SAT vs ACT Math Score 2017 by State")
plt.ylabel("ACT Average Math Score", fontsize = 10)
plt.xlabel("SAT Average Math Score", fontsize = 10);

# %% [markdown]
# There is no clear relationship between SAT and ACT Math scores

# %% [markdown]
# ## SAT vs. ACT verbal/reading scores for 2017

# %%
# Establish the size of the figure.
plt.figure(figsize=(12, 6))

# Create scatter plot of SAT versus ACT 2017.
plt.scatter(final['evidence-based_reading_and_writing_sat_17'],
            final['reading_act_17']);

plt.title("SAT vs ACT Reading Score 2017 by State")
plt.ylabel("ACT Average Reading Score", fontsize = 10)
plt.xlabel("SAT Average Reading Score", fontsize = 10);

# %% [markdown]
# There is no clear relationship between SAT and ACT Reading scores

# %% [markdown]
# ## SAT vs. ACT total/composite scores for 2017

# %%
# Establish the size of the figure.
plt.figure(figsize=(12, 6))

# Create scatter plot of SAT versus ACT 2017.
plt.scatter(final['total_sat_17'],
            final['composite_act_17']);

plt.title("SAT vs ACT Math Score 2017 by State")
plt.ylabel("ACT Average Composite Score", fontsize = 10)
plt.xlabel("SAT Average Total Score", fontsize = 10);

# %% [markdown]
# There is no clear relationship between SAT Total scores and ACT Composite scores

# %% [markdown]
# ## Total scores for SAT 2017 vs. 2018

# %%
# Establish the size of the figure.
plt.figure(figsize=(12, 6))

# Create scatter plot of SAT versus ACT 2017.
plt.scatter(final['total_sat_17'],
            final['total_sat_18']);

plt.title("SAT 2017 vs SAT 2018 Total Score by State")
plt.ylabel("SAT Average Total Score 2018", fontsize = 10)
plt.xlabel("SAT Average Total Score 2017", fontsize = 10);

# %% [markdown]
# There is a positive correlation between the 2017 and 2018 SAT Total scores. It seems that states that perform well in the exam consistantly perform well. While state that perfomed poorer also performed poorer the following year.

# %% [markdown]
# ## Composite scores for ACT 2017 vs. 2018

# %%
# Establish the size of the figure.
plt.figure(figsize=(12, 6))

# Create scatter plot of SAT versus ACT 2017.
plt.scatter(final['composite_act_17'],
            final['composite_act_18']);

plt.title("ACT 2017 vs ACT 2018 Composite Score by State")
plt.ylabel("ACT Average Composite Score 2018", fontsize = 10)
plt.xlabel("ACT Average Composite Score 2017", fontsize = 10);

# %% [markdown]
# There is a positive correlation between the 2017 and 2018 ACT Composite scores. It seems that states that perform well in the exam consistantly perform well. While state that perfomed poorer also performed poorer the following year.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
final.head()
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17  participation_sat_17  \
# 0            19.7            19.4              19.2                  0.05
# 1            20.4            19.9              19.8                  0.38
# 2            20.1            19.8              19.7                  0.30
# 3            19.7            19.5              19.4                  0.03
# 4            23.1            22.2              22.8                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  ...  \
# ...

# %% [markdown]
# # Boxplot (Participation)

# %%
# Code
final_part = final[['participation_act_17','participation_act_18', 'participation_sat_17', 'participation_sat_18']]
plt.figure(figsize=(15,6))
sns.boxplot(data= final_part, orient='v').set_title("Participation Rates", fontsize=20)
# final.boxplot(column=['participation_act_17','participation_sat_17', 'participation_act_18', 'participation_sat_18'])
# plt.xticks([1,2,3,4],labels=(['ACT 17', 'SAT 17', 'ACT 18', 'SAT 18']))
# Out:
# Text(0.5, 1.0, 'Participation Rates')

# %% [markdown]
# The majority of students in the states choose to take ACT compared to the SAT. However, the median of the participation rates for ACT has fallen whereas the median for SAT has increase, suggesting a change in state references.

# %% [markdown]
# # BoxPlot (SAT Test scores)

# %%
final_sat = final[['math_sat_17','math_sat_18', 'evidence-based_reading_and_writing_sat_17', 'evidence-based_reading_and_writing_sat_18']]
plt.figure(figsize=(15,6))
sns.boxplot(data= final_sat, orient='v').set(xticklabels=['SAT Math 17', 'SAT Math 18', 'SAT Reading 17', 'SAT Reading 18'])
# plt.figure(figsize=(15,6))
# final.boxplot(column=['math_sat_17','math_sat_18', 'evidence-based_reading_and_writing_sat_17', 'evidence-based_reading_and_writing_sat_18'])
# plt.xticks([1,2,3,4],labels=(['SAT Math 17', 'SAT Math 18', 'SAT Reading 17', 'SAT Reading 18']))
# Out:
# [[Text(0, 0, 'SAT Math 17'),
#   Text(0, 0, 'SAT Math 18'),
#   Text(0, 0, 'SAT Reading 17'),
#   Text(0, 0, 'SAT Reading 18')]]

# %% [markdown]
# The median of the SAT test score have fallen from 2017 to 2018. Even the 3rd quartile has reduced for SAT math, showing the students are doing poorer in the test.

# %%
final_total = final[['total_sat_17','total_sat_18']]
plt.figure(figsize=(6,6))
sns.boxplot(data= final_total, orient='v').set(xticklabels=['SAT Total 17', 'SAT Total 18'])

# plt.figure(figsize=(10,6))
# final.boxplot(column=['total_sat_17','total_sat_18'])
# plt.xticks([1,2],labels=(['SAT Total 17', 'SAT Total 18']))
# Out:
# [[Text(0, 0, 'SAT Total 17'), Text(0, 0, 'SAT Total 18')]]

# %% [markdown]
# The total scores is the combination of both math and reading test in the SATs. Therefore, the median scores are going to drop from 2017 to 2018.

# %% [markdown]
# # BoxPlot (ACT Test scores)

# %%
final_act = final[['math_act_17','math_act_18', 'english_act_17', 'english_act_18', 'reading_act_17', 'reading_act_18', 'science_act_17', 'science_act_18']]
plt.figure(figsize=(15,6))
sns.boxplot(data= final_act, orient='v').set(xticklabels=['ACT Math 17', 'ACT Math 18', 'ACT English 17', 'ACT English 18', 'ACT Reading 17', 'ACT Reading 18', 'ACT Science 17', 'ACT Science 18'])

# plt.figure(figsize=(15,6))
# final.boxplot(column=['math_act_17','math_act_18', 'english_act_17', 'english_act_18', 'reading_act_17', 'reading_act_18', 'science_act_18', 'science_act_18'])
# plt.xticks([1,2,3,4,5,6,7,8],labels=(['ACT Math 17', 'ACT Math 18', 'ACT English 17', 'ACT English 18', 'ACT Reading 17', 'ACT Reading 18', 'ACT Science 17', 'ACT Science 18']))
# Out:
# [[Text(0, 0, 'ACT Math 17'),
#   Text(0, 0, 'ACT Math 18'),
#   Text(0, 0, 'ACT English 17'),
#   Text(0, 0, 'ACT English 18'),
#   Text(0, 0, 'ACT Reading 17'),
#   Text(0, 0, 'ACT Reading 18'),
#   Text(0, 0, 'ACT Science 17'),
#   Text(0, 0, 'ACT Science 18')]]

# %% [markdown]
# The median of all the test scores have fallen from 2017 to 2018. Most students are faring poorer in the recent years even thought the range of results might have increased

# %%
final_composite = final[['composite_act_17','composite_act_18']]
plt.figure(figsize=(6,6))
sns.boxplot(data= final_composite, orient='v').set(xticklabels=['ACT Composite 17', 'ACT Composite 18'])
# plt.figure(figsize=(10,6))
# final.boxplot(column=['math_act_17','math_act_18'])
# plt.xticks([1,2],labels=(['ACT Total 17', 'ACT Total 18']))
# Out:
# [[Text(0, 0, 'ACT Composite 17'), Text(0, 0, 'ACT Composite 18')]]

# %% [markdown]
# Composite score is the combination of all the ACT test scores. So if all the medians went down, the median score for the composites would also fall as well

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ## Pairplot to look for any correlation between different Columns

# %%
sns.pairplot(final.iloc[:,:11])

# %% [markdown]
# # Scatter Plot (ACT Participation vs SAT Participation)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,6))
sns.regplot(x=final['participation_act_17'],y=final['participation_sat_17'], ax=ax1)
sns.regplot(x=final['participation_act_18'],y=final['participation_sat_18'], ax=ax2)

# %% [markdown]
# This is a scatterplot with regression line of the participation rates between both Exams in both years. There is a negative relationship between both Exams. This shows that students in most states either take the SAT exams or ACT only.

# %% [markdown]
# # Scatter Plot (ACT Participation vs Composite Scores)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,6))
sns.regplot(x=final['participation_act_17'],y=final['composite_act_17'], ax=ax1)
sns.regplot(x=final['participation_act_18'],y=final['composite_act_18'], ax=ax2)

# %% [markdown]
# This shows the relationship between ACT participations rate and Composite scores of the ACT Exams. It seems the higher the participation rates of the state, the lower the average scores that the state gets

# %% [markdown]
# # Scatter Plot (SAT Participation vs Total Scores)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,6))
sns.regplot(x=final['participation_sat_17'],y=final['total_sat_17'], ax=ax1)
sns.regplot(x=final['participation_sat_18'],y=final['total_sat_18'], ax=ax2)

# %% [markdown]
# This shows the relationship between SAT participation rates and Total scores of the SAT Exams. It seems the higher the participation rates of the state, the lower the average scores that the state gets

# %% [markdown]
# ## Plots to support Descriptive and Inferential Section

# %%
sns.distplot(final['english_act_17']).set_title("English test score")
# Out:
# Text(0.5, 1.0, 'English test score')

# %%
sns.distplot(final['english_act_18']).set_title("English test score")
# Out:
# Text(0.5, 1.0, 'English test score')

# %%
sns.distplot(final['reading_act_18']).set_title("Reading test score")
# Out:
# Text(0.5, 1.0, 'Reading test score')

# %%
sns.distplot(final['math_sat_17']).set_title("Math test score")
# Out:
# Text(0.5, 1.0, 'Math test score')

# %%
sns.distplot(final['science_act_17']).set_title("Science test score")
# Out:
# Text(0.5, 1.0, 'Science test score')

# %%
sns.distplot(final['science_act_18']).set_title("Science test score")
# Out:
# Text(0.5, 1.0, 'Science test score')

# %%
sns.distplot(final['composite_act_17']).set_title("Composite test score")
# Out:
# Text(0.5, 1.0, 'Composite test score')

# %%
sns.distplot(final['composite_act_18']).set_title("Composite test score")
# Out:
# Text(0.5, 1.0, 'Composite test score')

# %%
sns.distplot(final['evidence-based_reading_and_writing_sat_17']).set_title("Reading/Writing test score")
# Out:
# Text(0.5, 1.0, 'Reading/Writing test score')

# %%
sns.distplot(final['evidence-based_reading_and_writing_sat_18']).set_title("Reading/Writing test score")
# Out:
# Text(0.5, 1.0, 'Reading/Writing test score')

# %%
sns.distplot(final['total_sat_17']).set_title("Total score")
# Out:
# Text(0.5, 1.0, 'Total score')

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe().T
# Out:
#                                            count       mean        std  \
# participation_act_17                        50.0     0.6592   0.321107
# english_act_17                              50.0    20.8620   2.324307
# math_act_17                                 50.0    21.1360   1.973990
# reading_act_17                              50.0    21.9560   2.046317
# science_act_17                              50.0    21.4100   1.731962
# composite_act_17                            50.0    21.4660   2.004241
# participation_sat_17                        50.0     0.3860   0.345602
# evidence-based_reading_and_writing_sat_17   50.0   570.8600  44.385146
# math_sat_17                                 50.0   558.6600  45.839832
# total_sat_17                                50.0  1129.6200  89.913085
# participation_act_18                        50.0     0.6232   0.341141
# composite_act_18                            50.0    21.4540   2.111312
# ...

# %% [markdown]
# ## SAT 2017 and 2018
# - participation_sat_17
#     - The interquartile range is the spread of the distribution is 0.650 - 0.04 = 0.61(75% - 25%). The mean is 0.386 and the median is 0.34. Since the mean > median, it means the distribution is skewed to the right.
# - evidence-based_reading_and_writing_sat_17
#     - The interquartile range is the spread of the distribution is 613.5 - 535.25 = 78.25 (75% - 25%). The mean is 570.86 and the median is 559.5. Since the mean is almost the same as the median, there is no skewness in the distribution. However there are 2 peaks in the distribution, it is not normal.
# - math_sat_17
#     - The interquartile range is the spread of the distribution is 601 - 524 = 77 (75% - 25%). The mean is 558.66 and the median is 549.5. Since the mean is almost the same as median, it means there is not any skewness in the distribution. It is not a normal distribution
# - total_sat_17
#     - The interquartile range is the spread of the distribution is 1214 - 1057 = 157 (75% - 25%). The mean is 1129.62 and the median is 1107.5. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However, there are 2 peaks and is not a normal distribution.
# - participation_sat_18
#     - The interquartile range is the spread of the distribution is 0.745 - 0.0425 = 0.7025(75% - 25%). The mean is 0.4482 and the median is 0.5. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However there are 2 peaks and is not a normal distribution.
# - evidence-based_reading_and_writing_sat_18
#     - The interquartile range is the spread of the distribution is 612.75 - 535 = 77.75 (75% - 25%). The mean is 565.02 and the median is 552. Since the mean > median, there is a slight skewness to the right and the distribution has 2 peaks.
# - math_sat_18
#     - The interquartile range is the spread of the distribution is 594.25 - 524.23 = 70.02 (75% - 25%). The mean is 557.76 and the median is 545. Since the mean > median, there is a slight skewness to the right of the distribution.
# - total_sat_18
#     - The interquartile range is the spread of the distribution is 1207 - 1062.25 = 144.75(75% - 25%). The mean is 1122.88 and the median is 1098.5. Since the mean > median, the distribution is skewed to the right.

# %% [markdown]
# ## ACT 2017 and 2018
# - participation_act_17
#     - The interquartile range which is the spread of the distribution is 1 - 0.31 = 0.69 (75% - 25%). The mean is 0.6592 and the median is 0.71. Since the mean < median. This would show that the distribution is skewed to the left. As shown in the histogram above, it would seem that the distribution is heavily skewed.
# - english_act_17
#     - The interquartile range which is the spread of the distribution is 23.1 - 19 = 4.1(75% - 25%). Majority of the random values will be in this range. The mean is 20.862 and the median is 20.55. Since mean is more or less the same as the median, it means that there would not be any skewness the distribution. It is not a normal distribution either
# - math_act_17
#     - The interquartile range is the spread of the distribution is 23 - 19.4 = 3.6(75% - 25%). The mean is 21.136 and the median is 20.9.  Since the mean > median, the distribution is skewed to the right.
# - reading_act_17
#     - The interquartile range is the spread of the distribution is 23.875 - 20.425 = 2.375(75% - 25%). The mean is 21.956 and the median is 21.7. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However the distribution is not a normal distribution either.
# - science_act_17
#     - The interquartile range is the spread of the distribution is 22.275 - 19.9 = 2.375(75% - 25%). The mean is 20.992 and the median is 21.1. Since the mean is almost the same as median, it means there is not any skewness in the distribution. The distribution looks quite similar to a normal distribution.
# - composite_act_17
#     - The interquartile range is the spread of the distribution is 23.4 - 19.8 = 3.6(75% - 25%). The mean is 21.466 and the median is 21.4. Since the mean is almost the same as median, it means there is not any skewness in the distribution. The distribution is not like a normal distribution.
# - participation_act_18
#     - The interquartile range is the spread of the distribution is 1 - 0.2775 = 0.7225(75% - 25%). The mean is 0.6232 and the median is 0.66. Since the mean < median, it means the distribution is skewed heavily to the left.
# - english_act_18
#     - The interquartile range is the spread of the distribution is 23.6 - 19.1 = 3.6(75% - 25%). The mean is 20.934 and the median is 20.05. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However it is not a normal distribution and actually has 2 peaks in the distribution.
# - math_act_18
#     - The interquartile range is the spread of the distribution is 23.175 - 19.4 = 3.775(75% - 25%). The mean is 21.0940 and the median is 20.65. Since the mean > median, it means there is some skewness to the right in the distribution.
# - reading_act_18
#     - The interquartile range is the spread of the distribution is 24 - 20.425 = 3.575(75% - 25%). The mean is 21.968 and the median is 21.45. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However it is not a normal distribution.
# - science_act_18
#     - The interquartile range is the spread of the distribution is 23.075 - 19.775 = 3.3(75% - 25%). The mean is 21.312 and the median is 20.95. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However the distribution is not a normal distribution.
# - composite_act_18
#     - The interquartile range is the spread of the distribution is 23.65 - 19.925 = 3.725(75% - 25%). The mean is 21.454 and the median is 21.05. Since the mean is almost the same as median, it means there is not any skewness in the distribution. However, it is not a normal Distribution.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, we do not observe this trend. Most of the data is either skewed to a certain direction or have 2 peaks.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# - Math
#     - The assumption does not hold for Math results as the distributions are all slightly skewed to the right. Estimates taken from the distribution would tend to be on the lower side as distribution is skewed.
# - Reading
#     - The assumption does not hold for reading although the distributions for ACT reading is quite close to the normal distribution, while SAT reading has 2 peaks. Some estimates can still be made from the ACT reading scores but they may not be as accurate as a normal distribution. Values of the estimates taken from the SAT may have a wider range.
# - Rates
#     - The assumption does not hold for rates. ACT exam rates are skewed to the left, whereas SAT exam rates are al skewed to the right. Estimates made would be more towards the skew direction and would give inaccurate estimates of the population.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# NO, it does not make sense to conduct statistical inference on the participation rates. We do not have enough data about the population size to conduct a statistical inference. The anularity of the data in the table is only the participation rates of every state. The distribution of the participation rates are also far from normal.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# No, we are able to conduct statistical inference to compare the SAT and ACT Math scores. We cant test the scores between SAT and ACT as the scales that are used to measure the exam results are completely different. The means and standard deviations of respective exams would naturally be significantly different.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
final[(final['state'] == "Colorado")|(final['state'] == "Ohio")|(final['state'] == "Utah")][['state',"participation_act_17","participation_act_18","participation_sat_17","participation_sat_18"]]
# Out:
#        state  participation_act_17  participation_act_18  \
# 5   Colorado                  1.00                   0.3
# 34      Ohio                  0.75                   1.0
# 43      Utah                  1.00                   1.0
#
#     participation_sat_17  participation_sat_18
# 5                   0.11                  1.00
# 34                  0.12                  0.18
# 43                  0.03                  0.04

# %% [markdown]
# Both SAT and ACT Exams are both universally accepted by the US collages and are collage admission exams. Students are not required to take both exams. The idea of taking both exams is just to demonsrate Collage readiness.

# %% [markdown]
# ### Ohio

# %% [markdown]
# Ohio had a 75% Participation rate in ACT for 2017 and suddenly jumps to 100% participation rate while the SAT participation rate remained constant. After further research, I noticed that Ohio's State policy is that all 11th grade students must either take the ACT or SAT exams except for [students who are developmentally disabled or who have limited English skills because they’ve been in the country for less than two years may opt out](https://www.dispatch.com/news/20170228/ohio-schools-must-now-give-act-or-sat-to-all-juniors) (Quoted from the website). This would explain the small % of student that did not take either exams. The exams are provided with no cost so it would not burden the students. It is also stated that most Ohio district have chosen to take the ACT exams which would explain the 100% participation rates in 2018

# %% [markdown]
# ### Colorado

# %% [markdown]
# Colorado has a 100% participation rate for ACT in 2017 and 11% participation rate for SAT exams. But in 2018, the participation rate for ACT dropped to 30% while the participation rate for SAT jumped to 100%. Why is that? [It was stated in the website that as of 2018, all highschoolers in Colorado must take the SAT exams](https://www.testive.com/colorado-sat-change-2017/). [The reason for the switch from ACT exams to SAT exams is because The state Department of Education announced that the selection committee chose The College Board, makers of the SAT, over the ACT testing company.](https://www.chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/) (Quoted from the website). Therefore the state of Colorado decided to change the mandatory exam to SATs.

# %% [markdown]
# ### Utah

# %% [markdown]
# Utah manages to maintain ACT exams at 100% on both 2017 and 2018. After some research, [it is shown that all students in the State of Utah has to take the ACT exams in their high school years](https://www.edweek.org/ew/section/multimedia/states-require-students-take-sat-or-act.html). That is pretty much how they maintained the 100% participation rates

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ### Some of the key take aways are:
#
# 1) Students in the different state either took the ACT exams or the SAT exams. There is a negative correlation between the 2 participation rates in the scatterplots and heatmap.
#
# 2) There is also a negative correlation between the participation rates of the ACT and SAT exams and the composite and total scores respectively. This shows that the states with lower participation rates actually has better average scores and those states with higher participation rates fared poorly.
#
# 3) From the box plots above, i have noticed that the median scores for all the different test scores has fallen. The students are performing worse as the years pass.
#
# 4) The median participation rates of the SAT tests have slightly increased from 2017 to 2018, while median participation rates for ACT test have slightly decreased. More states are opting to take the SATs instead of the ACTs.

# %%
final.describe()
# Out:
#        participation_act_17  english_act_17  math_act_17  reading_act_17  \
# count             50.000000       50.000000     50.00000       50.000000
# mean               0.659200       20.862000     21.13600       21.956000
# std                0.321107        2.324307      1.97399        2.046317
# min                0.080000       16.300000     18.00000       18.100000
# 25%                0.310000       19.000000     19.40000       20.425000
# 50%                0.710000       20.550000     20.90000       21.700000
# 75%                1.000000       23.100000     23.00000       23.875000
# max                1.000000       25.500000     25.30000       26.000000
#
#        science_act_17  composite_act_17  participation_sat_17  \
# count       50.000000         50.000000             50.000000
# mean        21.410000         21.466000              0.386000
# std          1.731962          2.004241              0.345602
# ...

# %%
final[(final['participation_act_18'] < 0.5)|(final['participation_sat_18'] < 0.5)][['state',"participation_act_18",'composite_act_18',"participation_sat_18",'total_sat_18']].head()
# Out:
#         state  participation_act_18  composite_act_18  participation_sat_18  \
# 0     Alabama                  1.00              19.1                  0.06
# 1      Alaska                  0.33              20.8                  0.43
# 2     Arizona                  0.66              19.2                  0.29
# 3    Arkansas                  1.00              19.4                  0.05
# 4  California                  0.27              22.7                  0.60
#
#    total_sat_18
# 0        1166.0
# 1        1106.0
# 2        1149.0
# 3        1169.0
# 4        1076.0

# %% [markdown]
# From the table above, I have selected the State of Alaska. From this [website](https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/) The graduating students of Alaska is no longer required to take either the SAT or ACT test to graduate and obtain their diplomas. This would explain the low participation rates in the State. Also, the universities in Alaska still require the students to submit their SAT and ACT scores, this mean that there are lesser students going for their degrees in Alaska. The scores of the student who takes the tests are below the country's average score.
#
# ### Some Recommendations to help increase participation rates would be:
#
# 1) Right now in Alaska, students have to pay for themselves and sacrifice their weekends to go take the exams. A method that they could follow is the method that [Florida has taken](https://www.orlandosentinel.com/news/education/os-ne-act-sat-florida-scores-20181024-story.html), which is to offer **Free** SAT or ACT School day events, where the students can take the exams for free in school during the weekdays so it will be less hassle for the students, so they would not choose to pass on the exams just because it is troublesome.
#
# 2) From the boxplots and scatterplots above, there might be a possibility that graduates are skipping out of the ACT and SAT exams because they are not confident in their abilities to take these exams. As shown in the charts, the scores from the exams have been steadily dropping and the negative correlation with scores and participation rates. So, maybe the Collage Board could start implementing SAT/ACT exams preperation lessons and courses in the highschools for the students to better prepare them for the exams. This would increase their confidences levels and would entice them to sit for the exams.
#
# 3) The collage board should start promoting and reemphasizing the importance of getting a collage education. Since Alaska Universities still require the students to take the exams, if the graduates recognise the importance of a collage education, they would be more prone to sit for the exams and thus increasing the participation rates of the SAT/ACT scores.
